# %%
# !pip install pandas
# !pip install Sastrawi
# !pip install tqdm
# Out:
# Requirement already satisfied: pandas in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: Sastrawi in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: tqdm in /home/muliaandiki/Kuliah/PI/project/techscope/.venv/lib/python3.12/site-packages (4.67.1)

# %%
import os
import pandas as pd
import re
import string
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from tqdm import tqdm
from multiprocessing import Pool, cpu_count, freeze_support
from tqdm import tqdm
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# `Case Folding`

# %%
def case_folding(text):
    """Mengubah teks menjadi huruf kecil."""
    if pd.isna(text):
        return ""
    return str(text).lower()

def step1_casefolding(
    input_file="./device.csv",
    save_to="step_data",
    output_filename="step1_casefolding.csv"
):
    os.makedirs(save_to, exist_ok=True)
    output_path = os.path.join(save_to, output_filename)

    if not os.path.exists(input_file):
        print(f"❌ File {input_file} tidak ditemukan.")
        return

    df = pd.read_csv(input_file)
    print(f"🔹 Melakukan Case Folding pada file: {input_file}")

    required_cols = [
        "title", "content", "brand", "model", "processor",
        "ram", "storage", "display", "camera", "battery",
        "os", "tags"
    ]

    for col in required_cols:
        # Terapkan Case Folding
        df[col] = df[col].astype(str).apply(case_folding)

    df.to_csv(output_path, index=False, encoding='utf-8')
    
    print(f"✅ Step 1 (Case Folding) selesai — hasil disimpan di: {output_path}")
    return df # Mengembalikan DataFrame untuk digunakan di Sel 2

# Jalankan Step 1
df_step1 = step1_casefolding()
# Out:
# 🔹 Melakukan Case Folding pada file: ./device.csv
# ✅ Step 1 (Case Folding) selesai — hasil disimpan di: step_data/step1_casefolding.csv

# %% [markdown]
# `cleaning`

# %%
import pandas as pd
import os
import re
from tqdm import tqdm

def remove_noise(text):
    """
    Menghapus kontaminasi teks (deskripsi iPhone/Galaxy A16/Redmi Note) 
    dari kolom 'content' dengan mencari pola tertentu.
    """
    if pd.isna(text) or not isinstance(text, str):
        return ""
    
    # Pola 1: iPhone 16E/A18
    text = re.sub(r'deskripsi detail komparasi spesifikasi iphone 16e.*?tutup lengkap', '', text, flags=re.DOTALL)
    
    # Pola 2: Galaxy A16
    text = re.sub(r'layar fhd super amoled galaxy a16.*?tutup lengkap', '', text, flags=re.DOTALL)
    
    # Pola 3: Redmi Note 14 / Flagship Camera
    text = re.sub(r'deskripsi spesifikasi flagship level camera 108mp.*?tutup lengkap', '', text, flags=re.DOTALL)

    return text.strip()


def cleaning(text):
    """Melakukan Cleaning Kritis dan membersihkan simbol."""
    if pd.isna(text):
        return ""
    
    text = str(text) # Sudah lowercase dari Step 1
    
    # A. Hapus Noise KRITIS (aplikasikan hanya pada 'content' jika perlu, 
    # namun di sini diaplikasikan pada semua kolom karena data Frame sudah dimuat)
    text = remove_noise(text)
   
    # B. Hapus simbol/karakter non-alfanumerik (pertahankan angka dan spasi)
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)

    # C. Hapus spasi berulang
    text = re.sub(r"\s+", " ", text).strip()

    return text

def step2_cleaning(
    df, # Menerima DataFrame dari Step 1
    save_to="step_data",
    output_filename="step2_cleaning.csv"
):
    os.makedirs(save_to, exist_ok=True)
    output_path = os.path.join(save_to, output_filename)

    if df is None:
        print("❌ DataFrame Step 1 tidak tersedia.")
        return
    
    print("🧹 Memulai Step 2: Cleaning Kritis (Hapus Noise & Simbol)...")

    required_cols = [
        "title", "content", "brand", "model", "processor",
        "ram", "storage", "display", "camera", "battery",
        "os", "tags"
    ]

    for col in tqdm(required_cols, desc="Applying Cleaning"):
        # Terapkan Cleaning
        df[col] = df[col].astype(str).apply(cleaning)

    df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"✅ Step 2 (Cleaning Kritis) selesai — hasil disimpan di: {output_path}")

step2_cleaning(df_step1)
# Out:
# 🧹 Memulai Step 2: Cleaning Kritis (Hapus Noise & Simbol)...
# Applying Cleaning: 100%|██████████| 12/12 [00:00<00:00, 52.73it/s]
# ✅ Step 2 (Cleaning Kritis) selesai — hasil disimpan di: step_data/step2_cleaning.csv

# %% [markdown]
# `Tokenizing`

# %%
def tokenizing(text):
    if pd.isna(text):
        return []

    # Pisahkan angka-huruf (Contoh: '4gb' menjadi '4 gb')
    text = re.sub(r'([0-9]+)([a-zA-Z]+)', r'\1 \2', text)
    text = re.sub(r'([a-zA-Z]+)([0-9]+)', r'\1 \2', text)

    # Tokenisasi
    tokens = text.split()
    return tokens

def step3_tokenizing(
    input_file="step_data/step2_cleaning.csv",
    output_file="step_data/step3_tokenizing.csv"
):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)

    if not os.path.exists(input_file):
        print(f"❌ File {input_file} tidak ditemukan.")
        return

    print(f"🔹 Membaca file: {input_file}")
    df = pd.read_csv(input_file)

    required_cols = [
        "title", "content", "brand", "model", "processor",
        "ram", "storage", "display", "camera", "battery",
        "os", "tags"
    ]

    print("✂️ Melakukan tokenisasi teks...")

    for col in tqdm(required_cols, desc="Tokenizing"):
        df[col] = df[col].astype(str).apply(tokenizing)

    df.to_csv(output_file, index=False, encoding='utf-8')
    print(f"✅ Step 3 selesai — hasil disimpan di: {output_file}")


if __name__ == "__main__":
    print("🚀 Menjalankan Step 3 - Tokenizing...")
    step3_tokenizing(
        input_file="./step_data/step2_cleaning.csv",
        output_file="./step_data/step3_tokenizing.csv"
    )
# Out:
# 🚀 Menjalankan Step 3 - Tokenizing...
# 🔹 Membaca file: ./step_data/step2_cleaning.csv
# ✂️ Melakukan tokenisasi teks...
# Tokenizing: 100%|██████████| 12/12 [00:00<00:00, 28.08it/s]
# ✅ Step 3 selesai — hasil disimpan di: ./step_data/step3_tokenizing.csv

# %% [markdown]
# `Stopword Removal`

# %%
# File: step4_stopword.py
import ast
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# init stopwords
stop_factory = StopWordRemoverFactory()
stopwords_id = set(stop_factory.get_stop_words())

def parse_tokens_maybe(text):
    """Membantu mem-parsing token dari string list atau string biasa."""
    if isinstance(text, list): return [str(t).strip() for t in text if str(t).strip() != ""]
    if not isinstance(text, str): return []
    
    txt = text.strip()
    if (txt.startswith("[") and txt.endswith("]")) or (txt.startswith("('") or txt.startswith("['")):
        try:
            parsed = ast.literal_eval(txt)
            if isinstance(parsed, list):
                return [str(t).strip() for t in parsed if str(t).strip() != ""]
        except Exception: pass
    
    return [t.strip() for t in txt.split() if t.strip() != ""]


def remove_stopwords(tokens):
    """Menghapus stopword dari list token."""
    toks = parse_tokens_maybe(tokens)
    filtered = [word for word in toks if word not in stopwords_id]
    return filtered


def step4_stopword(
    input_file="step_data/step3_tokenizing.csv",
    output_file="step_data/step4_stopword.csv"
):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)

    if not os.path.exists(input_file):
        print(f"❌ File {input_file} tidak ditemukan.")
        return

    print(f"🔹 Membaca file: {input_file}")
    # Baca sebagai string agar parsing list (ast.literal_eval) lebih mudah
    df = pd.read_csv(input_file, dtype=str)  

    content_cols = ["content"]

    print("🧹 Menghapus stopword hanya dari kolom 'content'...")

    # Hanya remove stopword untuk content
    for col in tqdm(content_cols, desc="Removing Stopwords"):
        df[col] = df[col].apply(remove_stopwords)

    df.to_csv(output_file, index=False, encoding='utf-8')
    print(f"✅ Step 4 selesai — hasil disimpan di: {output_file}")


if __name__ == "__main__":
    print("🚀 Menjalankan Step 4 - Stopword Removal...")
    step4_stopword(
        input_file="./step_data/step3_tokenizing.csv",
        output_file="./step_data/step4_stopword.csv"
    )
# Out:
# 🚀 Menjalankan Step 4 - Stopword Removal...
# 🔹 Membaca file: ./step_data/step3_tokenizing.csv
# 🧹 Menghapus stopword hanya dari kolom 'content'...
# Removing Stopwords: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# ✅ Step 4 selesai — hasil disimpan di: ./step_data/step4_stopword.csv

# %% [markdown]
# `Steaming`

# %%
# File: step5_stemming.py (Membutuhkan modul multiprocessing dan tqdm)
import ast
from multiprocessing import Pool, cpu_count, freeze_support

_stemmer = None

def init_stemmer():
    """Inisialisasi stemmer di setiap worker multiprocessing"""
    global _stemmer
    _stemmer = StemmerFactory().create_stemmer()


def stemming_worker(tokens):
    """Worker function untuk multiprocessing. Menerima token list/string, mengembalikan stem string."""
    global _stemmer

    # Mengubah list token kembali menjadi string
    if isinstance(tokens, list):
        text = " ".join(tokens)
    else:
        # Menghapus format list string jika ada
        text = str(tokens).replace("[", "").replace("]", "").replace("'", "").replace(",", " ")

    try:
        # Pastikan text tidak kosong sebelum di-stem
        return _stemmer.stem(text.strip()) if text.strip() else ""
    except:
        return text


def process_batch(df_batch, num_cores):
    """Stemming paralel per batch"""
    # Gunakan kolom 'content'
    with Pool(num_cores, initializer=init_stemmer) as pool:
        konten_iter = pool.imap_unordered(stemming_worker, df_batch["content"])
        
        konten_stem = list(tqdm(
            konten_iter,
            total=len(df_batch),
            desc="📰 Stemming content",
            ncols=100,
            leave=False
        ))

    df_batch["content"] = konten_stem
    return df_batch


def step5_stemming_parallel_batch(
    input_file="step_data/step4_stopword.csv",
    output_file="step_data/step5_stemming.csv",
    batch_size=None,
):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)

    if not os.path.exists(input_file):
        print(f"❌ File {input_file} tidak ditemukan.")
        return

    total_cores = cpu_count()
    num_cores = max(1, total_cores - 1)
    if batch_size is None:
        batch_size = 2000

    print(f"🧠 Menggunakan {num_cores} dari {total_cores} core CPU. Batch size: {batch_size}\n")
    
    # Hitung total baris
    with open(input_file, encoding="utf-8", errors="ignore") as f: total_rows = sum(1 for _ in f) - 1
    print(f"📊 Total baris: {total_rows:,}")

    batch_iter = pd.read_csv(input_file, chunksize=batch_size, dtype=str)
    is_first = True

    for i, df_chunk in enumerate(batch_iter, start=1):
        print(f"\n🔹 Memproses batch {i}")
        df_processed = process_batch(df_chunk, num_cores)

        df_processed.to_csv(
            output_file,
            mode="a",
            index=False,
            header=is_first,
            encoding="utf-8",
        )

        is_first = False
        print(f"✅ Batch {i} selesai → disimpan")

    print("\n🎉 Semua batch selesai!")
    print(f"📁 Hasil akhir: {output_file}")


if __name__ == "__main__":
    freeze_support()
    print("🚀 Menjalankan Step 5 - Stemming Parallel Batch...")
    step5_stemming_parallel_batch(
        input_file="./step_data/step4_stopword.csv",
        output_file="./step_data/step5_stemming.csv",
    )
# Out:
# 🚀 Menjalankan Step 5 - Stemming Parallel Batch...
# 🧠 Menggunakan 11 dari 12 core CPU. Batch size: 2000
#
# 📊 Total baris: 1,987
#
# 🔹 Memproses batch 1
# ✅ Batch 1 selesai → disimpan
#
# 🎉 Semua batch selesai!
# 📁 Hasil akhir: ./step_data/step5_stemming.csv

# %% [markdown]
# `Detokenisasi`

# %%
# File: step6_detokenized.py
import pandas as pd
import ast
import re

# ===========================
#   PARSE LIST SAFELY
# ===========================
def parse_list(text):
    """Mengubah representasi string dari list menjadi string teks."""
    if isinstance(text, list):
        return " ".join(str(t) for t in text)

    try:
        # Mencoba mengevaluasi string yang berbentuk list
        parsed = ast.literal_eval(text)
        if isinstance(parsed, list):
            return " ".join(str(t) for t in parsed)
    except:
        pass

    return str(text)


# ===========================
#   NORMALIZER KHUSUS SPEK
# ===========================
def normalize_text(text):
    """Membersihkan dan menormalisasi teks spesifikasi (misalnya menggabungkan angka dan unit)."""
    if not isinstance(text, str):
        return text

    # Hilangkan koma, bracket, dan tanda kutip yang mungkin tersisa
    text = (
        text.replace(",", " ")
            .replace("[", "")
            .replace("]", "")
            .replace("'", "")
            .replace('"', ' ')
    )

    text = " ".join(text.split())  # bersihkan multi-spasi
    return text.capitalize() # Kapitalisasi sederhana


# ===========================
#       MAIN FUNCTION
# ===========================
def step6_detokenize_normalize(
    input_path: str = "./step_data/step5_stemming.csv",
    output_path: str = "./step_data/step6_detokenized.csv"
):
    print(f"📂 Membaca file: {input_path}")
    df = pd.read_csv(input_path)

    # Kolom yang harus di detokenisasi (konten sudah di-stem)
    text_cols = [
        "title", "content", "brand", "model", "processor",
        "ram", "storage", "display", "camera", "battery",
        "os", "tags"
    ]

    print("🧹 Detokenisasi dan Normalisasi semua kolom teks...")
    
    for col in tqdm(text_cols, desc="Detokenizing"):
        if col in df.columns:
            # 1. Detoken
            df[col] = df[col].apply(parse_list)
            # 2. Normalisasi
            df[col] = df[col].apply(normalize_text)

    df.to_csv(output_path, index=False)
    print(f"✅ Step 6 (Detokenisasi & Normalisasi) selesai → hasil disimpan ke {output_path}")

# Jalankan Step 6
if __name__ == "__main__":
    step6_detokenize_normalize()
# Out:
# 📂 Membaca file: ./step_data/step5_stemming.csv
# 🧹 Detokenisasi dan Normalisasi semua kolom teks...
# Detokenizing: 100%|██████████| 12/12 [00:00<00:00, 29.15it/s]
# ✅ Step 6 (Detokenisasi & Normalisasi) selesai → hasil disimpan ke ./step_data/step6_detokenized.csv

# %%
# File: step7_finalization.py
import pandas as pd
import os
import re

def clean_and_normalize_price(price_str):
    """Membersihkan string harga menjadi integer numerik (untuk filtering)."""
    if pd.isna(price_str): return None
    price_str = str(price_str).lower().replace('rp', '').replace('.', '').replace(',', '').strip()
    return int(price_str) if price_str.isdigit() else None

def map_device_type(text):
    """Menentukan tipe perangkat (untuk filtering kategori)."""
    if pd.isna(text): return 'Lain'
    text = str(text).lower()
    
    # Aturan sederhana: Mencari kata kunci di kolom title/tags/brand/model
    if 'laptop' in text or 'notebook' in text: return 'Laptop'
    if 'tablet' in text or 'matepad' in text: return 'Tablet'
    if 'hp' in text or 'handphone' in text or 'smartphone' in text: return 'Handphone'
    
    return 'Lain' # Default jika tidak teridentifikasi


def step7_finalization(
    input_file="./step_data/step6_detokenized.csv",
    output_file="./model/devices_df.csv" # Simpan langsung di folder model
):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)

    if not os.path.exists(input_file):
        print(f"❌ File {input_file} tidak ditemukan.")
        return

    print(f"🔹 Membaca file: {input_file}")
    df = pd.read_csv(input_file)

    # 1. Pembersihan & Normalisasi Harga 💰
    print("💰 Mengekstrak harga numerik...")
    df["harga_num"] = df["harga"].apply(clean_and_normalize_price)
    
    # 2. Ekstraksi Device Type (Kategori Kritis) 🏷️
    # Gunakan gabungan kolom untuk mendapatkan tipe perangkat yang akurat
    df["device_identifier"] = df["title"].astype(str) + " " + df["tags"].astype(str)
    df["device_type"] = df["device_identifier"].apply(map_device_type)
    df = df.drop(columns=['device_identifier'])

    # 3. Pembuatan Final Combined Text (untuk TF-IDF) 📝
    print("📝 Membuat kolom teks gabungan (combined_text) untuk TF-IDF...")
    text_cols_for_search = [
        "title", "brand", "model", "processor", "ram", "storage",
        "display", "camera", "battery", "os", "content", "tags"
    ]
    
    df["combined_text_final"] = df.apply(
        lambda row: " ".join(
            str(row[col]) for col in text_cols_for_search if col in df.columns and pd.notna(row[col])
        ), 
        axis=1
    )
    df["combined_text_final"] = df["combined_text_final"].apply(lambda x: re.sub(r'\s+', ' ', str(x)).strip())
    
    # Hapus kolom combined_text lama jika ada, ganti dengan yang baru
    if 'combined_text' in df.columns:
        df = df.drop(columns=['combined_text'])
    
    df.to_csv(output_file, index=False, encoding='utf-8')
    
    print(f"✅ Step 7 (Finalisasi Kritis) selesai — hasil disimpan di: {output_file}")
    print("\nContoh data kolom filter kritis:")
    print(df[["title", "device_type", "harga_num", "combined_text_final"]].head(3).to_string(index=False))


if __name__ == "__main__":
    step7_finalization()
# Out:
# 🔹 Membaca file: ./step_data/step6_detokenized.csv
# 💰 Mengekstrak harga numerik...
# 📝 Membuat kolom teks gabungan (combined_text) untuk TF-IDF...
# ✅ Step 7 (Finalisasi Kritis) selesai — hasil disimpan di: ./model/devices_df.csv
#
# Contoh data kolom filter kritis:
#                                   title device_type  harga_num                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                combined_text_final
# Realme 15 t 5 g 8 128 gb flowing silver   Handphone  3699000.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Realme 15 t 5 g 8 128 gb flowing silver Realme Realme 15 t 5 g flowing Mediatek dimensity 6400 max 6 nm octa core 2 x 2 5 ghz cortex a 76 6 x 2 0 ghz cortex a 55 8 gb 128 gb Amoled 1 b colors 120 hz 2160 hz pwm 1000 nits typ 1400 nits hbm 4000 nits peak 1080 x 2372 pixels 401 ppi density Belakang dual 50 mp f 1 8 27 mm wide 1 2 88 pdaf 2 mp f 2 4 depan 50 mp f 2 4 7000 mah Android 15 Deskripsi detail komparasi spesifikasi iphone 16 e dukung chip a 18 ambil foto resolusi super tinggi kamera fusion 48 mp kuat baterai super tahan lama kirim pesan teks jelajah laku lain lebih lama poin poin fitur utama chip a 18 tetap cepat hingga masa depan chip a 18 ada balik kuat baterai panjang hari game baru ios rutin buat iphone tetap asa baru lama tahun tahun datang kuat baterai super tahan lama kirim pesan teks jelajah tonton film acara putar video hingga 26 jam 1 kuat baterai baik iphone 6 1 inci 2 kamera sistem kamera fungsi milik kamera fusion 48 mp foto resolusi super tinggi telefoto 2 x kualitas optik ambil selfie pukau kamera depan 12 mp desain kokoh layar brilian layar 6 1 inci pukau teknologi oled ceramic shield bagi depan lebih tangguh kaca ponsel pintar mana tombol tindak akses cepat sesuai bagai aplikasi fitur favorit jadi lebih personal ios 18 sesuai layar utama layar kunci kirim pesan efek teks tapback emoji apa bagai lain fitur selamat penting deteksi tabrak iphone deteksi celaka mobil parah panggil bantu tak 3 privasi guna face id buka kunci masuk aman legal 1 kuat baterai variasi gantung guna konfigurasi lihat apple com iphone informasi 2 layar milik sudut lengkung ukur persegi layar milik ukur diagonal 6 06 inci iphone 16 e 6 12 inci iphone 16 6 69 inci iphone 16 plus 6 27 inci iphone 16 pro 6 86 inci iphone 16 pro max area bidang layar ukur lebih kecil 3 iphone 16 e deteksi celaka mobil parah panggil bantu perlu panggil wi fi koneksi seluler tutup lengkap Handphone smartphone realme mediatek 5 g
#              Vivo y 21 d 4 128 gb black   Handphone  2099000.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Vivo y 21 d 4 128 gb black Vivo Vivo y 21 d Unisoc t 7225 12 nm octa core 2 x 2 0 ghz cortex a 75 6 x 1 8 ghz cortex a 55 4 gb 128 gb Lcd 60 90 hz 1608 720 pixels Belakang 50 mp f 1 8 0 08 mp f 3 0 depan 5 mp f 2 2 6500 mah Android 15 Deskripsi spesifikasi new vision layar 4 r 4 sudut bulat nyaman seluruh empat sudut bulat rancang presisi sudut r layar satu mulus bingkai buat mata lebih nyaman beri tampil lebih pukau desain 4 r tekstur matte sentuh rasa suka hasil akhir matte tekstur kilau satin tarik perhati asa premium tangan padu anggun nyaman genggam 7 79 mm lebih tipis notebook rancang nyaman panjang hari tebal 7 79 mm berat 181 g leku ergonomis pas sempurna genggam 7 79 mm lebih tipis 7000 mah baterai lebih awet hari penuh sisa tengah daya tinggal rasa khawatir habis baterai baterai titan 7000 mah siap tani aktivitas maraton siang malam 60 w fast charge lebih cepat tunggu baterai besar 7000 mah isi 60 w isi 50 31 menit colok lanjut aktivitas jeda dual 50 mp kamera al depan belakang momen foto jadi lebih indah cantik alami detail nyata potret lihat tawan algoritma cantik cerdas hadir sentuh alami tetap jaga tekstur kulit autentik al edit genie say it edit it get it fitur ai edit genie sama realme 15 series 5 g mana tinggal edit guna suara ucap imajinasi biar ai edit genie ubah al edit genie edit gambar perintah suara edit selesai satu kata dukung lebih 20 bahasa filter portrait baru tunjuk pesona cahaya lima filter portrait unik tambah efek soft focus cahaya ubah momen jadi kenang indah layar amoled 4000 nits 4 r comfort tetap lihat bawah sinar matahari layar terang tiap sudut bulat simetris hadir warna lebih vivid lebih hidup tetap nyaman mata nikmat tampil lebih jernih baik luar ruang 6050 mm sistem dingin airflow vc stay cooler dominate longer sistem dingin besar kelas kurang panas lebih cepat main game atau sedang guna intensif ip 66 68 69 best waterproof dukung foto underwater serta lindung air debu baik kurang rasa khawatir smartphone sengaja jatuh air atau kena siram air tawar antenna array matrix 2 0 jamin koneksi tetap stabil dual stereo speakers suara lebih nyaring main game atau nonton video realme ui 6 0 next ai lebih efisien mini capsule dukung 10 skenario interaktif tutup lengkap Handphone smartphone vivo
#        Infinix smart 9 hd 4 64 gb black   Handphone  1149000.0 Infinix smart 9 hd 4 64 gb black Infinix Infinix smart 9 hd Mediatek helio octa core processor octa core 8 x 2 2 ghz cortex a 53 4 gb 64 gb Ips lcd 500 nits 720 1600 pixels Belakang 13 mp af f 1 85 depan 8 mp f 2 0 Nan Android 14 Deskripsi spesifikasi desain aspirasional ungu lavender warna ungu lembut kena sinar matahari pesona mikat energi bunga semarak hitam angkasa inspirasi bintang bintang kelap kelip warna hitam sinar anggun kosmik tenang desain compact 3 d indah leku desain tipis compact 3 d beri kesan premium nyaman genggam sentuh akhir pukau akses instan bingkai ramping inspirasi logam madu tipis gaya matte premium lengkap sensor sidik jari praktis bagi samping desain kamera flagship desain kamera dynamic light cahaya cerah madu gaya fungsi ubah warna dinamis notifikasi gak habis habis kuat ip 68 69 69 tahan air ekstrem tahan air tinggi sertifikasi ip 69 ip 69 ip 68 guna bawah air tahan hujan tahan air segala kondisi fitur water ejection getar mikro keluar air cepat lindung port speaker korosi korsleting suara rendam rangka flagship tiga lapis tahan air lengkap rangka flagship tiga lapis tahan air tingkat lapis luar lindung internal makin canggih pasti daya tahan maksimal bahkan kondisi basah ekstrem 6500 mah baterai bluevolt tahan 3 hari baterai besar 6500 mah desain tipis berkat teknologi bluevolt 6 beri alam guna gak habis habis 5 tahun baterai anti nge drop baterai tahan lama jaga sehat baterai 80 lama 5 tahun guna pasti kerja baterai tetap awet walaupun pakai jangka waktu lama 44 w flashcharge isi daya super cepat nikmat isi daya super cepat 44 w flashcharge hemat waktu buat y 21 d siap guna kejap lindung aman 29 dimensi lindung y 21 d lonjak daya panas listrik statis risiko isi daya lain tahan banting ekstrem dukung sertifikasi sgs gold label five stars kuat bantal kelas militer lindung baik jatuh lindung flagship guardian glass rancang lindung ekstrem buat guardian glass kuat ion ganda inti kuat struktur bantal lindung pasti lindung komprehensif case lindung tahan bentur casing smartphone teknologi airspring beri lindung stylish pegang aman tahan gores unggul uji tahan ekstrem perangkat lewat rangkai uji pasti daya tahan andal performa luar biasa guna hari hari 50 bulan lancar os lancar batas nikmat performa lancar buka aplikasi file jangka waktu panjang khawatir jadi turun performa 8 gb 8 gb extended ram multitasking lancar ram hingga 8 gb 8 gb pasti multitasking lancar pindah aplikasi mudah semua butuh simpan besar hingga 256 gb rom pernah habis ruang kenang momen comes with ai ai circle to search ketuk lingkar temu cari apa layar cukup lingkar sorot coret ketuk perlu tangkap layar ai screen translation teman jalan bagai bahasa bilah sisi baru google lens mungkin terjemah artikel situs web sekali ketuk cocok jalan bagai bahasa audio imersif layar ultra terang dual stereo speaker 400 audio booster audio sempurna speaker stereo ganda volume 400 nikmat volume hingga 400 panggil jernih media imersif navigasi bahkan lingkung bising ultra o screen jernih tajam kapan mana nikmat jernih takjub layar ultra o ukur 6 68 refresh rate 90 hz halus nyaman mata bahkan bawah sinar matahari kamera utama 50 mp jernih 50 mp kamera underwater tangkap detail sempurna tangkap foto jelas detail kamera utama 50 mp hd jepret sempurna tak lupa kamera underwater temu ajaib air temu ajaib air 50 mp kamera underwater lengkap ip 68 69 69 tahan air ekstrem seru gakhabishabis portrait hd kamera depan selfie jernih cerah segala kondisi cahaya tangkap selfie takjub kamera depan 5 mp hd aura light ai photo enhance foto takjub sempurna tingkat jernih wajah kembali detail foto lama resolusi rendah jaga kenang harga tutup lengkap Handphone smartphone infinix mediatek

# %%
# File: step8_modeling.py
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import pandas as pd
import os

def tokenize(text):
    """Fungsi sederhana untuk tokenisasi (memecah string menjadi list kata)."""
    return str(text).split()


def step8_remodel(
    input_file="./model/devices_df.csv",
    save_to="./model"
):
    print("🔹 Memuat data final untuk pemodelan ulang...")
    
    if not os.path.exists(input_file):
        print(f"❌ File input {input_file} tidak ditemukan. Pastikan Step 7 sudah dijalankan.")
        return

    df = pd.read_csv(input_file)
    
    if "combined_text_final" not in df.columns:
        print("❌ Kolom 'combined_text_final' tidak ditemukan. Jalankan Step 7 terlebih dahulu.")
        return

    os.makedirs(save_to, exist_ok=True)
    
    # --- 1. MODELING TF-IDF ---
    print("\n1. Membuat Model TF-IDF...")
    tfidf_vectorizer = TfidfVectorizer(
        max_features=50000,
        ngram_range=(1, 2)
    )

    tfidf_matrix = tfidf_vectorizer.fit_transform(df["combined_text_final"])

    print(f"✅ TF-IDF Matrix dibuat dengan shape: {tfidf_matrix.shape}")
    
    # Simpan Aset TF-IDF
    with open(os.path.join(save_to, "tfidf_vectorizer.pkl"), "wb") as f:
        pickle.dump(tfidf_vectorizer, f)
    with open(os.path.join(save_to, "tfidf_matrix.pkl"), "wb") as f:
        pickle.dump(tfidf_matrix, f)
    print("💾 Model TF-IDF berhasil disimpan.")


    # --- 2. PREPARASI JACCARD ---
    print("\n2. Mempersiapkan Token untuk Jaccard Similarity...")
    
    # Membuat list of tokens dari kolom combined_text_final
    jaccard_tokens = df["combined_text_final"].apply(tokenize).tolist()
    
    # Simpan Aset Jaccard
    with open(os.path.join(save_to, "jaccard_tokens.pkl"), "wb") as f:
        pickle.dump(jaccard_tokens, f)
        
    print(f"✅ Jaccard Tokens berhasil dibuat. Total {len(jaccard_tokens)} dokumen.")
    print("💾 Jaccard tokens berhasil disimpan.")


    print("\n🎉 Step 8 (Modeling Ulang) selesai.")

if __name__ == "__main__":
    step8_remodel()
# Out:
# 🔹 Memuat data final untuk pemodelan ulang...
#
# 1. Membuat Model TF-IDF...
# ✅ TF-IDF Matrix dibuat dengan shape: (1987, 50000)
# 💾 Model TF-IDF berhasil disimpan.
#
# 2. Mempersiapkan Token untuk Jaccard Similarity...
# ✅ Jaccard Tokens berhasil dibuat. Total 1987 dokumen.
# 💾 Jaccard tokens berhasil disimpan.
#
# 🎉 Step 8 (Modeling Ulang) selesai.
